# %%
import pandas as pd

# %%
folder =  "/home/nineleaps/Downloads"
filename = "sales_updated.csv"
path = f'{folder}/{filename}'
path
# Out:
# '/home/nineleaps/Downloads/sales_updated.csv'

# %%
df = pd.read_csv(path)
df
# Out:
#           Date Region      Product  Amount Customer ID
# 0   2024-01-07  North     D1-Shirt    1000        C001
# 1   15/01/2024   EAst   G2-Blazers    1200        C004
# 2      24/2/20  SOUTH  K3-Trousers    1500        C003
# 3   2024-02-13  West       D1Shirt    2000        C002
# 4   2024-03-19  South     D1-Shirt       0        C003
# 5      13/3/24    NaN   G2-Blazers    1800        C001
# 6   2024-04-03  South  K3-Trousers       0        C002
# 7   21/04/2024   East   G2-Blazers    2500        C004
# 8   2024-05-15   West  K3-Trousers    1500        C001
# 9      27/5/24  North  K3-Trousers    1500        C004
# 10  2024-06-16  South     D1-Shirt    3000        C003
# 11  2024-06-24   East   g2-Blazers    2000        C002

# %%
import pandas as pd

# %%
df["Region"] = df.Region.replace(
    {
        'EAst' : 'East',
        'SOUTH' : 'South',
    },
    regex = True
)
df.head()
# Out:
#          Date Region      Product  Amount Customer ID
# 0  2024-01-07  North     D1-Shirt    1000        C001
# 1  15/01/2024   East   G2-Blazers    1200        C004
# 2     24/2/20  South  K3-Trousers    1500        C003
# 3  2024-02-13  West       D1Shirt    2000        C002
# 4  2024-03-19  South     D1-Shirt       0        C003

# %%
df
# Out:
#           Date Region      Product  Amount Customer ID
# 0   2024-01-07  North     D1-Shirt    1000        C001
# 1   15/01/2024   East   G2-Blazers    1200        C004
# 2      24/2/20  South  K3-Trousers    1500        C003
# 3   2024-02-13  West       D1Shirt    2000        C002
# 4   2024-03-19  South     D1-Shirt       0        C003
# 5      13/3/24    NaN   G2-Blazers    1800        C001
# 6   2024-04-03  South  K3-Trousers       0        C002
# 7   21/04/2024   East   G2-Blazers    2500        C004
# 8   2024-05-15   West  K3-Trousers    1500        C001
# 9      27/5/24  North  K3-Trousers    1500        C004
# 10  2024-06-16  South     D1-Shirt    3000        C003
# 11  2024-06-24   East   g2-Blazers    2000        C002

# %%
df["Region"] = df["Region"].fillna("East")
df
# Out:
#           Date Region      Product  Amount Customer ID
# 0   2024-01-07  North     D1-Shirt    1000        C001
# 1   15/01/2024   East   G2-Blazers    1200        C004
# 2      24/2/20  South  K3-Trousers    1500        C003
# 3   2024-02-13  West       D1Shirt    2000        C002
# 4   2024-03-19  South     D1-Shirt       0        C003
# 5      13/3/24   East   G2-Blazers    1800        C001
# 6   2024-04-03  South  K3-Trousers       0        C002
# 7   21/04/2024   East   G2-Blazers    2500        C004
# 8   2024-05-15   West  K3-Trousers    1500        C001
# 9      27/5/24  North  K3-Trousers    1500        C004
# 10  2024-06-16  South     D1-Shirt    3000        C003
# 11  2024-06-24   East   g2-Blazers    2000        C002

# %%
df["Product"] = df.Product.replace(
    {
        'g2-Blazers' : 'G2-Blazers',
        'D1Shirt' : 'D1-Shirt',
    }, regex = True
)
df
# Out:
#           Date Region      Product  Amount Customer ID
# 0   2024-01-07  North     D1-Shirt    1000        C001
# 1   15/01/2024   East   G2-Blazers    1200        C004
# 2      24/2/20  South  K3-Trousers    1500        C003
# 3   2024-02-13  West      D1-Shirt    2000        C002
# 4   2024-03-19  South     D1-Shirt       0        C003
# 5      13/3/24   East   G2-Blazers    1800        C001
# 6   2024-04-03  South  K3-Trousers       0        C002
# 7   21/04/2024   East   G2-Blazers    2500        C004
# 8   2024-05-15   West  K3-Trousers    1500        C001
# 9      27/5/24  North  K3-Trousers    1500        C004
# 10  2024-06-16  South     D1-Shirt    3000        C003
# 11  2024-06-24   East   G2-Blazers    2000        C002

# %%
df.describe()
# Out:
#             Amount
# count    12.000000
# mean   1500.000000
# std     888.307891
# min       0.000000
# 25%    1150.000000
# 50%    1500.000000
# 75%    2000.000000
# max    3000.000000

# %%
df['Date'] = pd.to_datetime(df['Date'],errors = 'ignore', yearfirst = True)
df
# Out:
# /tmp/ipykernel_53100/2635993854.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df['Date'] = pd.to_datetime(df['Date'],errors = 'ignore', yearfirst = True)
#           Date Region      Product  Amount Customer ID
# 0   2024-01-07  North     D1-Shirt    1000        C001
# 1   15/01/2024   East   G2-Blazers    1200        C004
# 2      24/2/20  South  K3-Trousers    1500        C003
# 3   2024-02-13  West      D1-Shirt    2000        C002
# 4   2024-03-19  South     D1-Shirt       0        C003
# 5      13/3/24   East   G2-Blazers    1800        C001
# 6   2024-04-03  South  K3-Trousers       0        C002
# 7   21/04/2024   East   G2-Blazers    2500        C004
# 8   2024-05-15   West  K3-Trousers    1500        C001
# 9      27/5/24  North  K3-Trousers    1500        C004
# 10  2024-06-16  South     D1-Shirt    3000        C003
# 11  2024-06-24   East   G2-Blazers    2000        C002

# %%
df.Date = df.Date.replace(
    {
    '15/01/2024' : '2024-01-15',
    '24/2/20' : '2020-02-24',
    '13/3/24' : '2024-03-13',
    '21/04/2024' : '2024-04-21',
    '27/5/24' : '2024-05-27'
    },
regex = True
)
df
# Out:
#           Date Region      Product  Amount Customer ID
# 0   2024-01-07  North     D1-Shirt    1000        C001
# 1   2024-01-15   East   G2-Blazers    1200        C004
# 2   2020-02-24  South  K3-Trousers    1500        C003
# 3   2024-02-13  West      D1-Shirt    2000        C002
# 4   2024-03-19  South     D1-Shirt       0        C003
# 5   2024-03-13   East   G2-Blazers    1800        C001
# 6   2024-04-03  South  K3-Trousers       0        C002
# 7   2024-04-21   East   G2-Blazers    2500        C004
# 8   2024-05-15   West  K3-Trousers    1500        C001
# 9   2024-05-27  North  K3-Trousers    1500        C004
# 10  2024-06-16  South     D1-Shirt    3000        C003
# 11  2024-06-24   East   G2-Blazers    2000        C002

# %%
df["Date"] = pd.to_datetime(df["Date"], errors = "coerce")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         12 non-null     datetime64[ns]
#  1   Region       12 non-null     object
#  2   Product      12 non-null     object
#  3   Amount       12 non-null     int64
#  4   Customer ID  12 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 608.0+ bytes

# %%
df["Month"] = df["Date"].dt.month

# %%
month_sales = df.groupby("Month")["Amount"].sum()

# %%
highest_sales_month = month_sales.idxmax()
highest_sales_value = month_sales.max()

# %%
print(f"The month with the highest sales is: {highest_sales_month} with sales of {highest_sales_value}")
# Out:
# The month with the highest sales is: 6 with sales of 5000

# %%
region_sales = df.groupby("Region")["Amount"].sum().sort_values(ascending=False)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
region_sales.plot(kind="bar", color="skyblue")
plt.title("Region-wise Sales")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
month_sales.plot(kind="bar", color="lightcoral")
plt.title("Month-wise Sales")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()
